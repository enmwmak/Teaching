# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.8.0
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Learning/EIE4105/lab3/python/imagenet"
# Out:
# /content/drive/My Drive/Learning/EIE4105/lab3/python/imagenet

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Learning/EIE4105/lab3/python/imagenet

# %%
# !python3 imagenet_console.py
# Out:
# 2022-03-21 07:31:53.723165: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# Predicted: [('n02132136', 'brown_bear', 0.9985719), ('n02410509', 'bison', 0.0009712308), ('n02133161', 'American_black_bear', 0.00043203824)]

# %%
# %cd '/content/drive/My Drive/Learning/EIE4105/lab3/python/mnist'
# Out:
# /content/drive/My Drive/Learning/EIE4105/lab3/python/mnist

# %%
# !python3 mnist_dnn.py
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 784)
# 60000 train samples
# 10000 test samples
# 2022-03-19 03:30:00.034665: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Epoch 1/10
# 469/469 [==============================] - 7s 7ms/step - loss: 0.2752 - accuracy: 0.9165 - val_loss: 0.1148 - val_accuracy: 0.9654
# Epoch 2/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1108 - accuracy: 0.9661 - val_loss: 0.1024 - val_accuracy: 0.9668
# Epoch 3/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0778 - accuracy: 0.9761 - val_loss: 0.0992 - val_accuracy: 0.9699
# Epoch 4/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0622 - accuracy: 0.9801 - val_loss: 0.0745 - val_accuracy: 0.9759
# Epoch 5/10
# ...

# %%
# !mkdir -p '/content/drive/My Drive/Learning/EIE4105/lab3/python/mnist/models'

# %%
# !python3 mnist_cnn.py
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 2022-03-19 03:41:19.157229: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (BatchN  (None, 26, 26, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 11, 11, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
# ...

# %%
# !python3 mnist_console.py images/test/1/31.jpg
# Out:
# Loading models/mnist_cnn.h5
# 2022-03-18 10:37:45.652949: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# The query digit is '[1]'
# <Figure size 640x480 with 1 Axes>

# %%
# !ls models

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('images/test/1/31.jpg')
plt.imshow(img)

# %%
# !python mnist_1dcnn_vector.py
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples
# 2022-03-20 02:57:46.176895: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 775, 64)           704
#
#  batch_normalization (BatchN  (None, 775, 64)          256
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 387, 64)          0
#  )
#
#  dropout (Dropout)           (None, 387, 64)           0
#
#  conv1d_1 (Conv1D)           (None, 378, 64)           41024
#
#  batch_normalization_1 (Batc  (None, 378, 64)          256
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 189, 64)          0
# ...

# %%
# !ls -la ~/.keras/models
# Out:
# total 100600
# drwxr-xr-x 2 root root      4096 Mar 21 07:32 .
# drwxr-xr-x 3 root root      4096 Mar 21 07:31 ..
# -rw-r--r-- 1 root root     35363 Mar 21 07:32 imagenet_class_index.json
# -rw-r--r-- 1 root root 102967424 Mar 21 07:31 resnet50_weights_tf_dim_ordering_tf_kernels.h5

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
from keras.layers import BatchNormalization

# %%
import tensorflow as tf
model = tf.keras.applications.ResNet50(weights='imagenet')
# Out:
# ...
# 102981632/102967424 [==============================] - 1s 0us/step

# %%
import tensorflow
model = tensorflow.keras.applications.ResNet50(weights='imagenet')
